# %% [markdown]
# <a href="https://colab.research.google.com/github/Kristina-Boyarskaya/GU_Practic_3567/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('sample_data/california_housing_train.csv')

# %%
df.shape
# Out:
# (17000, 9)

# %%
df.dtypes

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df[
    (df['median_income'] < 2)
  ].median_house_value
# Out:
# 0        66900.0
# 1        80100.0
# 2        85700.0
# 4        65500.0
# 7        48500.0
#           ...
# 16984    70000.0
# 16989    58100.0
# 16990    78300.0
# 16994    76100.0
# 16998    85800.0
# Name: median_house_value, Length: 2005, dtype: float64

# %%
df[['longitude', 'latitude']]
# Out:
#        longitude  latitude
# 0        -114.31     34.19
# 1        -114.47     34.40
# 2        -114.56     33.69
# 3        -114.57     33.64
# 4        -114.57     33.57
# ...          ...       ...
# 16995    -124.26     40.58
# 16996    -124.27     40.69
# 16997    -124.30     41.84
# 16998    -124.30     41.80
# 16999    -124.35     40.54
#
# [17000 rows x 2 columns]

# %% [markdown]
# Выбрать данные где housing_median_age < 20 и
# median_house_value > 70000

# %%
df[
    (df['housing_median_age']<20) &
    (df['median_house_value']>70000)
]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 10       -114.60     33.62                16.0       3741.0           801.0
# 23       -114.98     33.82                15.0        644.0           129.0
# ...          ...       ...                 ...          ...             ...
# 16976    -124.17     40.75                13.0       2171.0           339.0
# 16983    -124.19     41.78                15.0       3140.0           714.0
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
#
# ...

# %% [markdown]
# Определить какое максимальное и минимальное
# значение median_house_value

# %%
print(df['median_house_value'].max(), df['median_house_value'].min())
# Out:
# 500001.0 14999.0

# %% [markdown]
# Показать максимальное median_house_value, где
# median_income = 3.1250

# %%
df[
    df['median_income'] == 3.1250
].median_house_value.max()
# Out:
# 380400.0

# %% [markdown]
# Узнать какая максимальная population в зоне
# минимального значения median_house_value

# %%
df[
    df['median_house_value'] == 14999
].population.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 568      490.0
# 3226     628.0
# 16643     85.0
# 16801     18.0
# Name: population, dtype: float64>
